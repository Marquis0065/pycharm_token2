# %%
import sys

sys.executable
# Out:
# 'C:\\ProgramData\\Anaconda3\\envs\\pythonProject1\\python.exe'

# %%
import dtale
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import dtale
#
# File C:\ProgramData\Anaconda3\envs\pythonProject1\lib\site-packages\dtale\__init__.py:3
#       1 import warnings
# ----> 3 from flask import Blueprint
#       5 with warnings.catch_warnings():
#       6     warnings.filterwarnings(
#       7         "ignore",
#       8         (
#    (...)
#      11         ),
#      12     )
#
# File C:\ProgramData\Anaconda3\envs\pythonProject1\lib\site-packages\flask\__init__.py:5
#       2 from markupsafe import Markup
#       4 from . import json as json
# ----> 5 from .app import Flask as Flask
#       6 from .app import Request as Request
#       7 from .app import Response as Response
#
# File C:\ProgramData\Anaconda3\envs\pythonProject1\lib\site-packages\flask\app.py:34
#      31 from werkzeug.utils import redirect as _wz_redirect
# ...

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
import pandas as pd
import dabl

df = pd.read_csv(r"C:\Users\fzh00\Desktop\文件\python资料\Python数据清洗基础\data补充\titanic_train.csv")
dabl.plot(df, target_col="Survived")
# Out:
# Target looks like classification
# Linear Discriminant Analysis training set score: 0.589
# [<AxesSubplot: title={'center': 'Target distribution'}, xlabel='count', ylabel='Survived'>,
#  [array([[<AxesSubplot: ylabel='Age'>, <AxesSubplot: >, <AxesSubplot: >,
#           <AxesSubplot: >],
#          [<AxesSubplot: ylabel='SibSp'>, <AxesSubplot: >, <AxesSubplot: >,
#           <AxesSubplot: >],
#          [<AxesSubplot: ylabel='Parch'>, <AxesSubplot: >, <AxesSubplot: >,
#           <AxesSubplot: >],
#          [<AxesSubplot: xlabel='Age', ylabel='Fare'>,
#           <AxesSubplot: xlabel='SibSp'>, <AxesSubplot: xlabel='Parch'>,
#           <AxesSubplot: xlabel='Fare'>]], dtype=object),
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 640x480 with 1 Axes>],
#  array([[<AxesSubplot: title={'center': 'Sex'}>,
#          <AxesSubplot: title={'center': 'Pclass'}>,
#          <AxesSubplot: title={'center': 'Embarked'}>]], dtype=object)]

# %%
import dtale
import pandas as pd
dtale.show(pd.read_csv(r"C:\Users\fzh00\Desktop\文件\python资料\Python数据清洗基础\data补充\titanic_train.csv"))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import dtale
#       2 import pandas as pd
#       3 dtale.show(pd.read_csv(r"C:\Users\fzh00\Desktop\文件\python资料\Python数据清洗基础\data补充\titanic_train.csv"))
#
# File C:\ProgramData\Anaconda3\envs\pythonProject1\lib\site-packages\dtale\__init__.py:3
#       1 import warnings
# ----> 3 from flask import Blueprint
#       5 with warnings.catch_warnings():
#       6     warnings.filterwarnings(
#       7         "ignore",
#       8         (
#    (...)
#      11         ),
#      12     )
#
# File C:\ProgramData\Anaconda3\envs\pythonProject1\lib\site-packages\flask\__init__.py:5
#       2 from markupsafe import Markup
#       4 from . import json as json
# ----> 5 from .app import Flask as Flask
#       6 from .app import Request as Request
#       7 from .app import Response as Response
#
# ...

# %%
klib.cat_plot(df, figsize=(50,15))
# Out:
# GridSpec(6, 5)

# %%
klib.dist_plot(df['Age'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
klib.corr_plot(df, annot=False)
# Out:
# <AxesSubplot: title={'center': 'Feature-correlation (pearson)'}>

# %%
import klib
import pandas as pd

df = pd.read_csv(r"C:\Users\fzh00\Desktop\文件\python资料\Python数据清洗基础\data补充\titanic_train.csv",encoding='gbk')
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %%
import os
os.__file__
# Out:
# 'C:\\ProgramData\\Anaconda3\\envs\\pythonProject1\\lib\\os.py'
