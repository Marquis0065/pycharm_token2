# %%
import random
import numpy as np

# %%
np.random.randint(1,10,20)
# Out:
# array([1, 8, 3, 8, 9, 5, 6, 2, 3, 4, 3, 2, 8, 9, 1, 8, 9, 6, 9, 7])

# %%
import pandas as pd
pd.DataFrame(np.random.rand(1000)).hist()
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %%
pd.DataFrame(np.random.randn(1000)).hist()
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %%
data1 = {"x":["201{}".format(i) for i in range(10)],
        "y":np.random.randint(2000,5000,10)}

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import matplotlib.pyplot as plt
#设置绘图风格
plt.style.use('seaborn')
#设置字体为黑色
plt.rcParams['font.family']='SimHei'
#显示符号
plt.rcParams['axes.unicode_minus']= False
# Out:
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_5720\1464687907.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
import matplotlib.pyplot as plt
plt.plot(data1['x'],data1['y'])

# %%
pd.DataFrame(data1).plot()
# Out:
# <AxesSubplot:>

# %%
import os
os.__file__
# Out:
# 'C:\\ProgramData\\Anaconda3\\envs\\pythonProject1\\lib\\os.py'

# %%
import seaborn as sns

# %%
sns.boxplot(data1['x'])
# Out:
# <AxesSubplot: >

# %%
sns.barplot(data1['y'])
# Out:
# <AxesSubplot: >

# %%
sns.histplot(data1['y'])
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
plt.boxplot(data1['y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23d113b3760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23d1058d8a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23d105e1c60>],
#  'medians': [<matplotlib.lines.Line2D at 0x23d1058e200>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23d1058e7d0>],
#  'means': []}

# %%
pd.DataFrame(data1).y.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
pd.DataFrame(data1).x.value_counts()
# Out:
# 2010    1
# 2011    1
# 2012    1
# 2013    1
# 2014    1
# 2015    1
# 2016    1
# 2017    1
# 2018    1
# 2019    1
# Name: x, dtype: int64

# %%
pd.DataFrame(data1['y']).hist()
# Out:
# array([[<AxesSubplot: title={'center': '0'}>]], dtype=object)
