# %% [raw]
# o#%%
# import telebot
# bot = telebot.TeleBot("6377312623:AAGz3ZSMVswWq0QVlihRPklw8b7skSBP16Y", parse_mode=None)
# bot.get_me()

# %%
bot.send_message(-677235937,'telebot 单独测试')

# %%
bot.send_document(-677235937,open(r"C:\Users\fzh00\Desktop\文件\Power BI 预习课程练习数据\销售总览BI图表.pbix",'rb'),timeout=1000)

# %%
import telebot
bot_2 = telebot.TeleBot("6377312623:AAGz3ZSMVswWq0QVlihRPklw8b7skSBP16Y", parse_mode=None)
bot_2.get_me()

# %%
import telebot
bot_3 = telebot.TeleBot("6377312623:AAGz3ZSMVswWq0QVlihRPklw8b7skSBP16Y", parse_mode=None)
bot_3.get_me()
# Out:
# bot_2	 bot_3	 pydev_jupyter_vars	 remove_imported_pydev_package	 sys	 telebot

# %%
who

# %%
bot_2.send_message(-677235937,'我是 bot_2')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\telegram\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# ...

# %%
bot_2.send_document(-677235937,open(r"C:\Users\fzh00\Desktop\W3School(2015).chm",'rb'),timeout=100)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\envs\telegram\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# ...

# %%
bot_2.send_photo(-677235937,open(r"C:\Users\fzh00\Desktop\W3School(2015).chm",'rb'),timeout=100)
